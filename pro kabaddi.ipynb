# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib 
import numpy as np

# %%
season1_2 = pd.read_excel("season1 & season2.xlsx")

# %%
season1_2.head()
# Out:
#    RANK            TEAM NAMES  TOTAL MATCHES PLAYED  TOTAL SCORE  \
# 0     1  Jaipur Pink Panthers                    16          579
# 1     2               U Mumba                    16          550
# 2     3         Patna Pirates                    16          504
# 3     4       Bengaluru Bulls                    16          498
# 4     5         Telugu Titans                    14          497
#
#    SUCCESSFUL RAIDS  SUCCESSFUL TACKLES  PERCENTAGE S_RAIDS  \
# 0               270                 158                0.55
# 1               270                 145                0.56
# 2               253                 124                0.50
# 3               225                 153                0.45
# 4               272                  96                0.59
#
#    PERCENTAGE S_TACKLES  STP  SUPER RAIDS  SUPER TACKLES  ALL OUT INFLICTED  \
# 0                  0.42   35            9             12                 29
# ...

# %%
season3_4 = pd.read_excel("season3 & season4.xlsx")

# %%
season3_4.head()
# Out:
#    RANK       TEAM NAMES  TOTAL MATCHES PLAYED  TOTAL SCORE  SUCCESSFUL RAIDS  \
# 0     1    Patna Pirates                    16          594               241
# 1     3    Puneri Paltan                    16          510               203
# 2     2          U Mumba                    16          502               206
# 3     4  Bengal Warriors                    16          460               213
# 4     5    Telugu Titans                    14          427               206
#
#    SUCCESSFUL TACKLES  PERCENTAGE S_RAIDS  PERCENTAGE S_TACKLES  STP  \
# 0                 175                0.46                  0.45   40
# 1                 174                0.36                  0.50   34
# 2                 163                0.37                  0.51   28
# 3                 137                0.34                  0.39   16
# 4                 101                0.42                  0.38   14
#
#    SUPER RAIDS  SUPER TACKLES  ALL OUT INFLICTED  ALL OUT CONCEDED  \
# ...

# %%
season5_6 = pd.read_excel("season5 & season6 & season7.xlsx")

# %%
season5_6.head()
# Out:
#    RANK             TEAM NAMES  TOTAL MATCHES PLAYED  TOTAL SCORE  \
# 0     1          Patna Pirates                    26         1050
# 1     2  Gujarat Fortunegiants                    24          775
# 2     3          Puneri Paltan                    24          766
# 3     4            U.P. Yoddha                    23          762
# 4     5        Bengal Warriors                    24          749
#
#    SUCCESSFUL RAIDS  SUCCESSFUL TACKLES  PERCENTAGE S_RAIDS  \
# 0               487                 252                0.54
# 1               379                 242                0.38
# 2               358                 226                0.36
# 3               351                 206                0.46
# 4               336                 191                0.42
#
#    PERCENTAGE S_TACKLES  STP  SUPER RAIDS  SUPER TACKLES  ALL OUT INFLICTED  \
# 0                  0.40   79           26             27                 55
# ...

# %%
all_seasons = pd.concat([season1_2,season3_4,season5_6], axis=0, sort= False)

# %%
all_seasons.head()
# Out:
#    RANK            TEAM NAMES  TOTAL MATCHES PLAYED  TOTAL SCORE  \
# 0     1  Jaipur Pink Panthers                    16          579
# 1     2               U Mumba                    16          550
# 2     3         Patna Pirates                    16          504
# 3     4       Bengaluru Bulls                    16          498
# 4     5         Telugu Titans                    14          497
#
#    SUCCESSFUL RAIDS  SUCCESSFUL TACKLES  PERCENTAGE S_RAIDS  \
# 0               270                 158                0.55
# 1               270                 145                0.56
# 2               253                 124                0.50
# 3               225                 153                0.45
# 4               272                  96                0.59
#
#    PERCENTAGE S_TACKLES  STP  SUPER RAIDS  SUPER TACKLES  ALL OUT INFLICTED  \
# 0                  0.42   35            9             12                 29
# ...

# %%
all_seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 0 to 23
# Data columns (total 14 columns):
# RANK                    56 non-null int64
# TEAM NAMES              56 non-null object
# TOTAL MATCHES PLAYED    56 non-null int64
# TOTAL SCORE             56 non-null int64
# SUCCESSFUL RAIDS        56 non-null int64
# SUCCESSFUL TACKLES      56 non-null int64
# PERCENTAGE S_RAIDS      56 non-null float64
# PERCENTAGE S_TACKLES    56 non-null float64
# STP                     56 non-null int64
# SUPER RAIDS             56 non-null int64
# SUPER TACKLES           56 non-null int64
# ALL OUT INFLICTED       56 non-null int64
# ALL OUT CONCEDED        56 non-null int64
# AVERAGE POINT SCORE     56 non-null float64
# dtypes: float64(3), int64(10), object(1)
# memory usage: 6.6+ KB

# %% [markdown]
# ## TASK 1

# %%
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,1,1)
sns.countplot(x='TEAM NAMES', hue="TOTAL SCORE", data=all_seasons)
plt.legend(loc='upper right')

# %%
d2 = pd.read_excel("dataset 2.xlsx")

# %%
d2.head()
# Out:
#            PLAYER NAME                  TEAM  SEASON
# 0   DEEPAK NIWAS HOODA  Jaipur Pink Panthers     1.0
# 1  AJINKYA ASHOK PAWAR  Jaipur Pink Panthers     1.0
# 2        DEEPAK NARWAL  Jaipur Pink Panthers     1.0
# 3          GUMAN SINGH  Jaipur Pink Panthers     1.0
# 4       LOKESH KAUSHIK  Jaipur Pink Panthers     1.0

# %%
d3 = pd.read_excel("dataset 3.xlsx")

# %%
d3.head()
# Out:
#    S.NO     PLAYER  NAME  SUCCESSFUL RAID   SUCCESSFUL TACKLE   SEASON
# 0     1       Anup Kumar            0.6078              0.4000       1
# 1     2  Rahul Chaudhari            0.6265              0.3225       1
# 2     3   Maninder Singh            0.7428              0.3684       1
# 3     4      Ajay Thakur            0.5350              0.2777       1
# 4     5  Kashiling Adake            0.5594              0.3600       1

# %%
fig = plt.figure(figsize=(30,30))
fig.add_subplot(1,1,1)
sns.countplot(x='TEAM NAMES', hue="RANK", data=all_seasons)
plt.legend(loc='upper right')

# %% [markdown]
# ## TASK 3

# %%
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,1,1)
sns.countplot(x='SUCCESSFUL RAIDS', hue="TEAM NAMES",data=all_seasons)
plt.legend(loc='upper right')

# %% [markdown]
# ## TASK 4

# %%
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,1,1)
sns.countplot(x='SUCCESSFUL TACKLES', hue="TEAM NAMES",data=all_seasons)
plt.legend(loc='upper right')

# %% [markdown]
# ## TASK 2

# %%
fig = plt.figure(figsize=(30,30))
fig.add_subplot(1,1,1)
sns.countplot(x='AVERAGE POINT SCORE', hue="TEAM NAMES",data=all_seasons)
plt.legend(loc='upper right')

# %% [markdown]
# ## TASK 5

# %%
fig = plt.figure(figsize=(30,30))
fig.add_subplot(1,1,1)
sns.countplot(x='STP', hue="TEAM NAMES",data=all_seasons)
plt.legend(loc='upper right')

# %%
d3.head(5)
# Out:
#    S.NO     PLAYER  NAME  SUCCESSFUL RAID   SUCCESSFUL TACKLE   SEASON
# 0     1       Anup Kumar            0.6078              0.4000       1
# 1     2  Rahul Chaudhari            0.6265              0.3225       1
# 2     3   Maninder Singh            0.7428              0.3684       1
# 3     4      Ajay Thakur            0.5350              0.2777       1
# 4     5  Kashiling Adake            0.5594              0.3600       1

# %%
d3.isnull().sum()
# Out:
# S.NO                  0
# PLAYER  NAME          0
# SUCCESSFUL RAID       0
# SUCCESSFUL TACKLE     0
# SEASON                0
# dtype: int64

# %%
sns.heatmap(d3.isnull(),yticklabels=False, cmap = "viridis")

# %% [markdown]
# ## TASK 6

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Anup Kumar','Rahul Chaudhari','Maninder Singh','Ajay Thakur','Kashiling Adake','Manjeet Chhillar',
               'Surjeet Narwal',
               'Sandeep Narwal','Jasvir Singh','Wazir Singh','Ravi Dalal','Nitin Madane','Rakesh Kumar','Rajesh Narwal',
               'Deepak Niwas Hooda',
               'Sukesh Hegde','Rishank Devadiga','Shabeer Bappu','Surender Nada','Mahesh Goud','Jang Kun Lee','Jitesh Joshi',
               'Dharmaraj Cheralathan','Sunil Jaipal','Shrikant Tewthia','Jasmer Singh Gulia','Rajesh Mondal',
               'Pawan Kumar Kadian',
               'Manoj Kumar','Rohit Rana','Mohit Chhillar','Parmod Narwal','Ran Singh','Nilesh Shinde','Prashant Chavan',
                'Kalimuthu Balamahendran','Mahipal Narwal','Amit Singh Chhillar','Ravinder Pahal','D. Suresh Kumar','Mangesh Bhagat',
               'Shyam Kumar Sah','Sachin Khambe','Wasim Sajjad','Gurpreet Singh','D. Gopu','Girish Maruti Ernak',
               'Mahendra Ganesh Rajput',
               'Deepak Kumar Dahiya','Pravin Niwale'] 
sucessful_raid = [0.6078,
0.6265,
0.7428,
0.535,
0.5594,
0.4011,
0,
0.5287,
0.4796,
0.581,
0.3799,
0.558,
0.5238,
0.4965,
0.5878,
0.6076,
0.5245,
0.5546,
0.7692,
0.4678,
0.6626,
0,
0.4193,
0,
0.4606,
0.35,
0.3979,
0.4942,
0.3333,
0,
1,
0.3333,
0.6875,
0.625,
0,
0,
0.2622,
0.25,
0,
0,
0,
0,
0,
0,
0,
0.4,
0.3333,
0.42,
0.3725,
0]
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(45,10))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 1')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Kashiling Adake',
'Manjeet Chhillar',
'Rahul Chaudhari',
'Deepak Niwas Hooda',
'Rajesh Narwal',
'Sandeep Narwal',
'Anup Kumar',
'Ajay Thakur',
'Jasvir Singh',
'Sandeep Kandola',
'Wazir Singh',
'Sukesh Hegde',
'Ravinder Pahal',
'Rohit Kumar Choudary',
'Kuldeep Singh',
'Deepak Narwal',
'Dharmaraj Cheralathan',
'Prashanth Kumar Rai',
'Rishank Devadiga',
'Mahendra Ganesh Rajput',
'Sonu Narwal',
'Jang Kun Lee',
'Gurvinder Singh',
'Ravi Dalal',
'Shabeer Bappu',
'Ran Singh',
'Surender Nada',
'Mohit Chhillar',
'Pravin Niwale',
'Sunil Jaipal',
'Jeeva Kumar',
'Meraj Sheykh',
'Ravi Kumar',
'Somvir Shekhar',
'Rajesh Mondal',
'Nilesh Shinde',
'Bhupender Singh',
'Joginder Singh Narwal',
'D. Suresh Kumar',
'Girish Maruti Ernak',
'Pradeep Kumar',
'Vishal Mane',
'Amit Hooda',
'Sunil',
'Sachin Khambe',
'Mahipal Narwal',
'Rakesh Narwal',
'Manoj Kumar',
'Shrikant Tewthia',
'Rakesh Singh Kumar']
sucessful_raid = [0.473,
0.3087,
0.5355,
0.3921,
0.4859,
0.315,
0.3032,
0.4157,
0.3216,
0,
0.422,
0.4661,
0.2352,
0.3333,
0.2,
0.5344,
0.4523,
0.5094,
0.3666,
0.4741,
0,
0.3428,
0.3283,
0.2945,
0.3709,
0.3714,
0.1363,
0,
0,
0,
0.1,
0.3857,
0,
0.1,
0.2894,
0.0476,
0.3492,
0,
0,
0,
0,
0,
0,
0.4,
0,
0.194,
0.4375,
0.08,
0.2702,
0]
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(45,10))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 2')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pardeep Narwal','Rishank Devadiga',
'Rohit Kumar',
'Manjeet Chhillar',
'Rahul Chaudhari',
'Jang Kun Lee',
'Nitin Tomar',
'Rajesh Narwal',
'Anup Kumar',
'Kashiling Adake',
'Deepak Niwas Hooda',
'CPO Surjeet Singh',
'Sukesh Hegde',
'Sandeep Narwal',
'Ajay Thakur',
'Rohit Baliyan',
'Sonu Narwal',
'Pawan Kumar Sehrawat',
'Rakesh Kumar',
'PO Surjeet Singh',
'Meraj Sheykh',
'Jasmer Singh Gulia',
'Mohit Chhillar',
'Surender Singh',
'Surjeet Narwal',
'Ran Singh',
'Selvamani K',
'Bajirao Hodage',
'Deepak Kumar Dahiya',
'Dharmaraj Cheralathan',
'Nilesh Shinde',
'Amit Om Prakash Rathi',
'Mahesh Goud',
'Girish Maruti Ernak',
'Ravinder Pahal',
'Shrikant Tewthia',
'Deepak Narwal',
'Fazel Atrachali',
'Sandeep Kumar Dhull',
'Ashish Kumar',
'Jeeva Kumar',
'Sunil',
'Manpreet Singh',
'Rajesh Mondal',
'Mahendra Ganesh Rajput',
'Jasvir Singh',
'Somvir',
'Tushar Patil',
'Kuldeep Singh',
'Anil Kumar']
sucessful_raid =[0.6203,
0.576,
0.573,
0.2631,
0.4182,
0.4293,
0.4812,
0.2979,
0.3636,
0.4385,
0.4394,
0.4121,
0.4178,
0.1636,
0.3513,
0.5046,
0,
0.409,
0.2642,
0.1666,
0.3857,
0,
0,
0.415,
0,
0.3508,
0.413,
0,
0.3557,
0.3,
0.1176,
0.3181,
0.2462,
0.0588,
0.2352,
0.3448,
0.5344,
0.5,
0,
0.3684,
0,
0.3333,
0,
0.409,
0.4072,
0.4901,
0,
0.3859,
0.2,
0.1333]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(45,10))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 3')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Rahul Chaudhari',
'Pardeep Narwal',
'Deepak Niwas Hooda',
'Rohit Kumar',
'Kashiling Adake',
'Jasvir Singh',
'Rajesh Narwal',
'Anup Kumar',
'Meraj Sheykh',
'Rakesh Kumar',
'Rishank Devadiga',
'Manjeet Chhillar',
'Sandeep Narwal',
'Jang Kun Lee',
'Ajay Thakur',
'Monu Goyat',
'Nilesh Salunke',
'Ajay Kumar',
'Rajesh Mondal',
'Nitin Madane',
'Amit Hooda',
'Fazel Atrachali',
'Mohit Chhillar',
'Selvamani K',
'Sachin Shingade',
'Kuldeep Singh',
'Dharmaraj Cheralathan',
'Joginder Singh Narwal',
'Ravinder Pahal',
'Ashish Kumar',
'Surender Nada',
'CPO Surjeet Singh',
'PO Surjeet Singh',
'Sandeep Kumar Dhull',
'Shabeer Bappu',
'Nitin Tomar',
'Ran Singh',
'Sonu Narwal',
'Vishal Mane',
'Vinod Kumar',
'Nilesh Shinde',
'Jeeva Kumar',
'Girish Maruti Ernak',
'Abolfazl Maghsodloumahali',
'Suresu Kumar',
'Bajirao Hodage',
'Mahipal Narwal',
'Somvir Shekhar',
'Pawan Kumar Kadian',
'Vinod Kumar']
sucessful_raid = [0.4492,
0.498,
0.4548,
0.3974,
0.4126,
0.366,
0.4489,
0.313,
0.3539,
0.4731,
0.4964,
0.3116,
0.2727,
0.5083,
0.4064,
0.3511,
0.4388,
0.57,
0.3518,
0.3333,
100,
0,
0.375,
0.4245,
0,
0.1066,
0.0714,
0.6666,
0,
0.2916,
0.2666,
0.4459,
0,
0,
0.24,
0.2946,
0.5555,
0,
0,
0,
0.0666,
0,
0,
0.6756,
0.3191,
0,
0.2857,
0,
0.303,
0.3114]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(45,10))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 4')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pardeep Narwal',
'Rohit Kumar',
'Ajay Thakur',
'Monu Goyat',
'Rahul Chaudhari',
'Maninder Singh',
'Deepak Niwas Hooda',
'Nitin Tomar',
'Sachin',
'Rishank Devadiga',
'Anup Kumar',
'K. Prapanjan',
'Pawan Kumar Kadian',
'Kashiling Adake',
'Wazir Singh',
'Nilesh Salunke',
'Meraj Sheykh',
'Shrikant Jadhav',
'Abolfazl Maghsodloumahali',
'Rajesh Mondal',
'Jang Kun Lee',
'Ajay Kumar',
'Deepak Narwal',
'Sandeep Narwal',
'Nitin Rawal',
'Surender Nada',
'Prashanth Kumar Rai',
'PO Surjeet Singh',
'Deepak Kumar Dahiya',
'Sukesh Hegde',
'Rohit Baliyan',
'Vishal Bhardwaj',
'Jaideep',
'Surender Singh',
'Girish Maruti Ernak',
'Tushar Patil',
'Jasvir Singh',
'Abozar Mohajermighani',
'Ran Singh',
'Vijay',
'CPO Surjeet Singh',
'Mahendra Ganesh Rajput',
'Amit Hooda',
'Vikash Khandola',
'Sunil Kumar',
'Surender Singh',
'Mahender Singh',
'Fazel Atrachali',
'Ravinder Pahal',
'Manjeet Chhillar']
sucessful_raid = [0.6296,
0.5239,
0.5233,
0.5232,
0.4466,
0.5177,
0.4777,
0.5107,
0.5389,
0.5409,
0.3985,
0.4019,
0.4295,
0.5112,
0.3948,
0.3967,
0.3287,
0.5058,
0.3956,
0.3345,
0.4198,
0.3463,
0.4545,
0.282,
0.4391,
0.1363,
0.5234,
0.0576,
0.3877,
0.3191,
0.3939,
0,
0,
0.519,
0.2777,
0.4102,
0.2904,
0.1666,
0.4444,
0.3253,
0.4041,
0.5229,
0,
0.0322,
0.0322,
0,
0.5,
0,
0.3333,
0.1724]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 5')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pawan Kumar Sehrawat',
'Pardeep Narwal',
'Siddharth Sirish Desai',
'Deepak Niwas Hooda',
'Maninder Singh',
'Ajay Thakur',
'Sachin Tanwar',
'Vikash Kandola',
'Naveen Kumar',
'Rohit Kumar',
'Rahul Chaudhari',
'Monu Goyat',
'Chandran Ranjit',
'Prashanth Kumar Rai',
'Shrikant Jadhav',
'K. Prapanjan',
'Rohit Baliyan',
'Rishank Devadiga',
'Nitin Tomar',
'Manjeet',
'Naveen',
'Nitesh Kumar',
'Meraj Sheykh',
'More GB',
'Parvesh Bhainswal',
'Nilesh Salunke',
'Kashiling Adake',
'Fazel Atrachali',
'Jang Kun Lee',
'Sunil Kumar',
'Ajinkya Ashok Pawar',
'Deepak Narwal',
'Vijay',
'Ran Singh',
'Sukesh Hegde',
'Sachin Kumar',
'Sandeep Kumar Dhull',
'Manjeet Chhillar',
'Sandeep Narwal',
'Mahender Singh',
 'Surender Singh',
'Rohit Gulia',
'Vishal Bhardwaj',
'Ravinder Pahal',
'Jaideep',
'PO Surjeet Singh',
'Monu',
'Girish Maruti Ernak',
'Mohsen Maghsoudloujafari',
'Abozar Mohajermighani']
sucessful_raid = [0.7226,
0.5959,
0.6791,
0.5355,
0.5478,
0.5231,
0.5191,
0.4956,
0.5602,
0.475,
0.4542,
0.5315,
0.4841,
0.5517,
0.4246,
0.4784,
0.5,
0.3816,
0.5235,
0.4603,
0.4559,
0.1428,
0.4413,
0.4593,
0,
0.4029,
0.4035,
0,
0.4619,
0,
0.4355,
0.5,
0.5405,
0.4027,
0.3863,
0.2808,
0,
0.2758,
0.2906,
0,
0,
0.3815,
0,
0,
0,
0.0555,
0.3629,
0.125,
0.2589,
0]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_raid)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_raid', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 6')
    plt.show()

# %%
plot_bar_x()

# %% [markdown]
# ## TASK 7

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Anup Kumar',
'Rahul Chaudhari',
'Maninder Singh',
'Ajay Thakur',
'Kashiling Adake',
'Manjeet Chhillar',
'Surjeet Narwal',
'Sandeep Narwal',
'Jasvir Singh',
'Wazir Singh',
'Ravi Dalal',
'Nitin Madane',
'Rakesh Kumar',
'Rajesh Narwal',
'Deepak Niwas Hooda',
'Sukesh Hegde',
'Rishank Devadiga',
'Shabeer Bappu',
'Surender Nada',
'Mahesh Goud',
'Jang Kun Lee',
'Jitesh Joshi',
'Dharmaraj Cheralathan',
'Sunil Jaipal',
'Shrikant Tewthia',
'Jasmer Singh Gulia',
'Rajesh Mondal',
'Pawan Kumar Kadian',
'Manoj Kumar',
'Rohit Rana',
'Mohit Chhillar',
'Parmod Narwal',
'Ran Singh',
'Nilesh Shinde',
'Prashant Chavan',
'Kalimuthu Balamahendran',
'Mahipal Narwal',
'Amit Singh Chhillar',
'Ravinder Pahal',
'D. Suresh Kumar',
'Mangesh Bhagat',
'Shyam Kumar Sah',
'Sachin Khambe',
'Wasim Sajjad',
'Gurpreet Singh',
'D. Gopu',
'Girish Maruti Ernak',
'Mahendra Ganesh Rajput',
'Deepak Kumar Dahiya',
'Pravin Niwale']
sucessful_tackle = [0.4,
0.3225,
0.3684,
0.2777,
0.36,
0.6071,
0,
0.6585,
0.3888,
0.4666,
0,
0.2727,
0.3437,
0.5098,
0.0909,
0.1904,
0.3823,
0.0796,
0.5543,
0.4444,
0.1428,
0,
0.5652,
0,
0.2432,
0.4523,
0.3846,
0.1428,
0.2698,
0.481,
0.3932,
0.3333,
0.6097,
0.3424,
0,
0,
0.5384,
0.358,
0.4531,
0.4827,
0,
0,
0,
0,
0,
0.3833,
0.3258,
0,
0.3333,
0]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 1')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Kashiling Adake',
'Manjeet Chhillar',
'Rahul Chaudhari',
'Deepak Niwas Hooda',
'Rajesh Narwal',
'Sandeep Narwal',
'Anup Kumar',
'Ajay Thakur',
'Jasvir Singh',
'Sandeep Kandola',
'Wazir Singh',
'Sukesh Hegde',
'Ravinder Pahal',
'Rohit Kumar Choudary',
'Kuldeep Singh',
'Deepak Narwal',
'Dharmaraj Cheralathan',
'Prashanth Kumar Rai',
'Rishank Devadiga',
'Mahendra Ganesh Rajput',
'Sonu Narwal',
'Jang Kun Lee',
'Gurvinder Singh',
'Ravi Dalal',
'Shabeer Bappu',
'Ran Singh',
'Surender Nada',
'Mohit Chhillar',
'Pravin Niwale',
'Sunil Jaipal',
'Jeeva Kumar',
'Meraj Sheykh',
'Ravi Kumar',
'Somvir Shekhar',
'Rajesh Mondal',
'Nilesh Shinde',
'Bhupender Singh',
'Joginder Singh Narwal',
'D. Suresh Kumar',
'Girish Maruti Ernak',
'Pradeep Kumar',
'Vishal Mane',
'Amit Hooda',
'Sunil',
'Sachin Khambe',
'Mahipal Narwal',
'Rakesh Narwal',
'Manoj Kumar',
'Shrikant Tewthia',
'Rakesh Singh Kumar']
sucessful_tackle = [0.25,
0.6071,
0.2647,
0.5901,
0.4736,
0.5211,
0.5833,
0.1666,
0.5555,
0,
0.2222,
0.1538,
0.625,
0,
0.5384,
0.4,
0.6176,
0.4,
0.5384,
0.125,
0,
0.1333,
0.2272,
0.25,
0.1666,
0.5849,
0.6029,
0.5833,
0,
0,
0.6551,
0.5526,
0.375,
0.5161,
0.0769,
0.5121,
0.4,
0.5172,
0.5357,
0.409,
0,
0.4905,
0.4074,
0.5789,
0,
0.4615,
0,
0.2653,
0.2903,
0.2881]
               
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 2')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pardeep Narwal',
'Rishank Devadiga',
'Rohit Kumar',
'Manjeet Chhillar',
'Rahul Chaudhari',
'Jang Kun Lee',
'Nitin Tomar',
'Rajesh Narwal',
'Anup Kumar',
'Kashiling Adake',
'Deepak Niwas Hooda',
'CPO Surjeet Singh',
'Sukesh Hegde',
'Sandeep Narwal',
'Ajay Thakur',
'Rohit Baliyan',
'Sonu Narwal',
'Pawan Kumar Sehrawat',
'Rakesh Kumar',
'PO Surjeet Singh',
'Meraj Sheykh',
'Jasmer Singh Gulia',
'Mohit Chhillar',
'Surender Singh',
'Surjeet Narwal',
'Ran Singh',
'Selvamani K',
'Bajirao Hodage',
'Deepak Kumar Dahiya',
'Dharmaraj Cheralathan',
'Nilesh Shinde',
'Amit Om Prakash Rathi',
'Mahesh Goud',
'Girish Maruti Ernak',
'Ravinder Pahal',
'Shrikant Tewthia',
'Deepak Narwal',
'Fazel Atrachali',
'Sandeep Kumar Dhull',
'Ashish Kumar',
'Jeeva Kumar',
'Sunil',
'Manpreet Singh',
'Rajesh Mondal',
'Mahendra Ganesh Rajput',
'Jasvir Singh',
'Somvir',
'Tushar Patil',
'Kuldeep Singh',
'Anil Kumar']
sucessful_tackle = [0.3846,
0.409,
0.5,
0.6161,
0.4137,
0.55,
0.3636,
0.5384,
0.3333,
0.2307,
0.3333,
0,
0.1875,
0.5789,
0.4444,
0.1176,
0,
0.4075,
0.5454,
0.64,
0.5526,
0.4222,
0.6216,
0.0909,
0,
0.4038,
0.1666,
0.4567,
0,
0.5344,
0.4761,
0.4,
0.0769,
0.5076,
0.4482,
0.3333,
0.4,
0.6956,
0.5245,
0.4098,
0.5,
0.4202,
0,
0.3333,
0.7,
0,
0,
0,
0.5384,
0.3725]
               
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 3')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Rahul Chaudhari',
'Pardeep Narwal',
'Deepak Niwas Hooda',
'Rohit Kumar',
'Kashiling Adake',
'Jasvir Singh',
'Rajesh Narwal',
'Anup Kumar',
'Meraj Sheykh',
'Rakesh Kumar',
'Rishank Devadiga',
'Manjeet Chhillar',
'Sandeep Narwal',
'Jang Kun Lee',
'Ajay Thakur',
'Monu Goyat',
'Nilesh Salunke',
'Ajay Kumar',
'Rajesh Mondal',
'Nitin Madane',
'Amit Hooda',
'Fazel Atrachali',
'Mohit Chhillar',
'Selvamani K',
'Sachin Shingade',
'Kuldeep Singh',
'Dharmaraj Cheralathan',
'Joginder Singh Narwal',
'Ravinder Pahal',
'Ashish Kumar',
'Surender Nada',
'CPO Surjeet Singh',
'PO Surjeet Singh',
'Sandeep Kumar Dhull',
'Shabeer Bappu',
'Nitin Tomar',
'Ran Singh',
'Sonu Narwal',
'Vishal Mane',
'Vinod Kumar',
'Nilesh Shinde',
'Jeeva Kumar',
'Girish Maruti Ernak',
'Abolfazl Maghsodloumahali',
'Suresu Kumar',
'Bajirao Hodage',
'Mahipal Narwal',
'Somvir Shekhar',
'Pawan Kumar Kadian',
'Vinod Kumar']
sucessful_tackle = [0.3636,
0.3333,
0.1428,
0.4375,
0.6111,
0.4285,
0.3584,
0.4166,
0.4,
0.5531,
0,
0.6027,
0.506,
0.2352,
0.125,
0.3076,
0.1,
0,
0.125,
0.1428,
0.573,
0.7222,
0.5402,
0,
0.5238,
0.5151,
0.619,
0.4927,
0.5138,
0.5227,
0.5322,
0.3333,
0.5068,
0.5223,
0.5789,
0.125,
0.4516,
0,
0.4696,
0,
0.5,
0.4193,
0.431,
0,
0.2307,
0.44,
0.3043,
0.3684,
0.1428,
0.1666]

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 4')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pardeep Narwal',
'Rohit Kumar',
'Ajay Thakur',
'Monu Goyat',
'Rahul Chaudhari',
'Maninder Singh',
'Deepak Niwas Hooda',
'Nitin Tomar',
'Sachin',
'Rishank Devadiga',
'Anup Kumar',
'K. Prapanjan',
'Pawan Kumar Kadian',
'Kashiling Adake',
'Wazir Singh',
'Nilesh Salunke',
'Meraj Sheykh',
'Shrikant Jadhav',
'Abolfazl Maghsodloumahali',
'Rajesh Mondal',
'Jang Kun Lee',
'Ajay Kumar',
'Deepak Narwal',
'Sandeep Narwal',
'Nitin Rawal',
'Surender Nada',
'Prashanth Kumar Rai',
'PO Surjeet Singh',
'Deepak Kumar Dahiya',
'Sukesh Hegde',
'Rohit Baliyan',
'Vishal Bhardwaj',
'Jaideep',
'Surender Singh',
'Girish Maruti Ernak',
'Tushar Patil',
'Jasvir Singh',
'Abozar Mohajermighani',
'Ran Singh',
'Vijay',
'CPO Surjeet Singh',
'Mahendra Ganesh Rajput',
'Amit Hooda',
'Vikash Khandola',
'Sunil Kumar',
'Surender Singh',
'Mahender Singh',
'Fazel Atrachali',
'Ravinder Pahal',
'Manjeet Chhillar']
sucessful_tackle = [0,
0.4444,
0.36,
0.3142,
0.2727,
0.1538,
0.4117,
0.3333,
0.56,
0.3125,
0.3833,
0.0588,
0,
0.5,
0.4814,
0.3888,
0.2162,
0.5454,
0.4285,
0.125,
0,
0,
0.2,
0.5098,
0.3846,
0.5555,
0.2,
0.5205,
0.2222,
0.1538,
0.3214,
0.5182,
0.461,
0.0869,
0.5765,
0.1875,
0.3333,
0.5603,
0.4642,
0.4457,
0.3636,
0.3333,
0.5213,
0.5643,
0.5643,
0.3815,
0.5044,
0.5757,
0.5,
0.5529] 

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 5')
    plt.show()

# %%
plot_bar_x()

# %%
import matplotlib.pyplot as plt
import numpy as np
player_name = ['Pawan Kumar Sehrawat',
'Pardeep Narwal',
'Siddharth Sirish Desai',
'Deepak Niwas Hooda',
'Maninder Singh',
'Ajay Thakur',
'Sachin Tanwar',
'Vikash Kandola',
'Naveen Kumar',
'Rohit Kumar',
'Rahul Chaudhari',
'Monu Goyat',
'Chandran Ranjit',
'Prashanth Kumar Rai',
'Shrikant Jadhav',
'K. Prapanjan',
'Rohit Baliyan',
'Rishank Devadiga',
'Nitin Tomar',
'Manjeet',
'Naveen',
'Nitesh Kumar',
'Meraj Sheykh',
'More GB',
'Parvesh Bhainswal',
'Nilesh Salunke',
'Kashiling Adake',
'Fazel Atrachali',
'Jang Kun Lee',
'Sunil Kumar',
'Ajinkya Ashok Pawar',
'Deepak Narwal',
'Vijay',
'Ran Singh',
'Sukesh Hegde',
'Sachin Kumar',
'Sandeep Kumar Dhull',
'Manjeet Chhillar',
'Sandeep Narwal',
'Mahender Singh',
'Surender Singh',
'Rohit Gulia',
'Vishal Bhardwaj',
'Ravinder Pahal',
'Jaideep',
'PO Surjeet Singh',
'Monu',
'Girish Maruti Ernak',
'Mohsen Maghsoudloujafari',
'Abozar Mohajermighani']
sucessful_tackle = [0.275,
0,
0.3333,
0.3157,
0,
0.0909,
0.6363,
0.2777,
0.4166,
0.3,
0.3684,
0.1481,
0.3333,
0.3333,
0.4545,
0.0909,
0.4375,
0.2105,
0.2222,
0.3947,
0.3255,
0.6493,
0.1875,
0.5714,
0.6213,
0.1904,
0.3695,
0.6384,
0.2727,
0.5428,
0.3076,
0.4444,
0.2954,
0.4772,
0.1578,
0.4257,
0.5234,
0.4876,
0.5061,
0.5163,
0.4881,
0.1578,
0.6315,
0.472,
0.4328,
0.4186,
0.5217,
0.4955,
0.5192,
0.5714]    

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(player_name))
    plt.figure(figsize=(50,20))
    plt.bar(player_name, sucessful_tackle)
    plt.xlabel('player_name', fontsize=5)
    plt.ylabel('sucessful_tackle', fontsize=5)
    plt.xticks(index, player_name, fontsize=10, rotation=90)
    plt.title('Season 6')
    plt.show()

# %%
plot_bar_x()

# %% [markdown]
# ## PREDICTION :

# %% [markdown]
# ## TASK 1 : WINNER OF THE LEAGUE - PATNA PIRATES
#
# ## TASK 2 : TOP TEAM IN POINTS TABLE - BENGAL WARRIORS
#
# ## TASK 3 : TEAM WITH HIGHEST SUCCESSFUL RAID POINTS - BENGAL WARRIORS
#
# ## TASK 4 : TEAM WITH HIGHEST SUCCESSFUL TACKLE POINTS - PUNERI PALTAN
#
# ## TASK 5 : TEAM WITH HIGHEST SPT - BENGALURU BULLS
#
# ## TASK 6 : PLAYER WITH HIGHEST SUCCESSFUL RAID PERCENTAGE - PRADEEP NARWAL
#
# ## TASK 7 : PLAYER WITH THE HIGHEST SUCCESSFUL TACKLE PERCENTAGE - FAZEL ATRACHALI
